# %%
import requests

def scrape_data(url, page):
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
        # Add any additional headers or authentication tokens required
    }

    response = requests.get(url, headers=headers)

    if response.status_code == 200:
        data = response.json()
        # Save the JSON data as a text file
        file_name = f"data_page_{page}.txt"
        with open(file_name, 'w') as file:
            file.write(str(data))
        print(f"Data for page {page} saved successfully!")
    else:
        print(f"Failed to retrieve data for page {page}. Status code: {response.status_code}")

for page in range(1, 358):  # Assuming there are 357 pages based on the provided JSON
    url = f"https://ibjjf.com/api/v1/academies/list.json?page={page}"
    scrape_data(url, page)
# Out:
# Failed to retrieve data for page 1. Status code: 406
# Failed to retrieve data for page 2. Status code: 406
# Failed to retrieve data for page 3. Status code: 406
# Failed to retrieve data for page 4. Status code: 406
# Failed to retrieve data for page 5. Status code: 406
# Failed to retrieve data for page 6. Status code: 406
# Failed to retrieve data for page 7. Status code: 406
# Failed to retrieve data for page 8. Status code: 406
# Failed to retrieve data for page 9. Status code: 406
# Failed to retrieve data for page 10. Status code: 406
# Failed to retrieve data for page 11. Status code: 406
# Failed to retrieve data for page 12. Status code: 406
# Failed to retrieve data for page 13. Status code: 406
# Failed to retrieve data for page 14. Status code: 406
# Failed to retrieve data for page 15. Status code: 406
# Failed to retrieve data for page 16. Status code: 406
# Failed to retrieve data for page 17. Status code: 406
# Failed to retrieve data for page 18. Status code: 406
# ...
